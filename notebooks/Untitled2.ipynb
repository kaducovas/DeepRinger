# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot

# %%
train = np.load('/home/caducovas/Train_sort0et_1_eta_1.npz')

# %%
train['arr_0'].shape
# Out:
# (205506, 100)

# %%
df = pd.DataFrame(train['arr_0'])
#df = pd.Series(train['arr_0'])
df
# Out:
#               0         1         2         3         4         5         6   \
# 0       0.086247  0.030461 -0.023969 -0.010959 -0.003626 -0.003728 -0.000809
# 1       0.020018  0.012558  0.011141  0.003656  0.005364  0.004271 -0.009400
# 2       0.051120  0.020307 -0.002284 -0.005358 -0.000431  0.000009  0.002167
# 3       0.023628  0.062731  0.012621 -0.004614  0.006771  0.002467 -0.004509
# 4       0.059349  0.006162 -0.000158  0.005150 -0.003564  0.002067  0.005620
# 5       0.018151  0.027214  0.015162  0.001448  0.007188 -0.002955 -0.004124
# 6       0.023969  0.006822  0.002063 -0.006861 -0.016812  0.006930  0.001921
# 7       0.024671  0.020033  0.006007  0.001877  0.006701  0.009425 -0.002806
# 8       0.087609  0.017698 -0.009960 -0.002294  0.006366 -0.001977  0.023666
# 9       0.060241  0.047761 -0.006615 -0.006172  0.005492 -0.010555 -0.001273
# 10      0.095040  0.030398 -0.007676 -0.003084 -0.000281 -0.005235  0.008478
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-6c47663005e0> in <module>()
# ----> 1 autocorrelation_plot(df)
#
# /usr/lib64/python2.7/site-packages/pandas/plotting/_misc.pyc in autocorrelation_plot(series, ax, **kwds)
#     557                 (data[h:] - mean)).sum() / float(n) / c0
#     558     x = np.arange(n) + 1
# --> 559     y = lmap(r, x)
#     560     z95 = 1.959963984540054
#     561     z99 = 2.5758293035489004
#
# /usr/lib64/python2.7/site-packages/pandas/plotting/_misc.pyc in r(h)
#     555     def r(h):
#     556         return ((data[:n - h] - mean) *
# --> 557                 (data[h:] - mean)).sum() / float(n) / c0
#     558     x = np.arange(n) + 1
#     559     y = lmap(r, x)
#
# KeyboardInterrupt:
